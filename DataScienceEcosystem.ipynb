# %% [markdown]
# # Data Science Tools and Ecosystem
# ![2-title.png](attachment:image.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.
# ![3-intro.png](attachment:image.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. Java
# ![4-dslanguages.png](attachment:image-2.png)

# %% [markdown]
# **Objectives:**
# * popular languages
# * popular libraries
# * popular tools
# ![10-objectives.png](attachment:image.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Scrapy
# 2. NumPy
# 3. SciPy
# 4. Pandas
# ![5-dslibraries.png](attachment:image-2.png)

# %% [markdown]
# | Data Science Tools |
# | :---: |
# |Jupyter Notebook|
# |Julia|
# |Keras |
# ![6-dstools.png](attachment:image-2.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python
# ![7-introarithmetic.png](attachment:image.png)

# %%
print("This a simple arithmetic expression to mutiply then add integers");

print ((3*4)+5);
# Out:
# This a simple arithmetic expression to mutiply then add integers
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:image.png)

# %%
print("This will convert 200 minutes to hours by diving by 60.");

minutes = 200;
hour = minutes // 60;

print (hour);
# Out:
# This will convert 200 minutes to hours by diving by 60.
# 3

# %% [markdown]
# ![9-hourstominutes.png](attachment:image.png)

# %% [markdown]
# ## Author
# Icy Wang
# ![11-authordetails.png](attachment:image.png)
